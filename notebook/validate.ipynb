# %%
import pandas as pd


df=pd.read_csv("/config/workspace/artifact/12032022__004055/data_ingestion/dataset/train.csv")
df
# Out:
#       class  aa_000  ab_000  ac_000  ad_000  ae_000  af_000  ag_000  ag_001  \
# 0       neg   30742     0.0   248.0   212.0    74.0   282.0     0.0     0.0
# 1       neg   27558     NaN     0.0     NaN     0.0     0.0     0.0     0.0
# 2       neg   11046     NaN     0.0     NaN     0.0     0.0     0.0     0.0
# 3       neg   33084     NaN   210.0   152.0     0.0     0.0     0.0     0.0
# 4       neg   41064     NaN    88.0    88.0     0.0     0.0     0.0     0.0
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 28945   neg   36782     NaN   238.0   222.0     0.0     0.0     0.0     0.0
# 28946   neg   27414     2.0   192.0     NaN     0.0     0.0     0.0     0.0
# 28947   neg   12576     NaN  1426.0  1500.0     0.0     0.0     0.0     0.0
# 28948   neg   40584     NaN   288.0   212.0     0.0     0.0     0.0     0.0
# 28949   neg      24     NaN    30.0    28.0     0.0     0.0     0.0     0.0
#
# ...

# %%
df.isnull().sum()/df.shape[0]
# Out:
# class     0.000000
# aa_000    0.000000
# ab_000    0.772228
# ac_000    0.059413
# ad_000    0.253541
#             ...
# ee_007    0.010535
# ee_008    0.010535
# ee_009    0.010535
# ef_000    0.048428
# eg_000    0.048394
# Length: 171, dtype: float64
